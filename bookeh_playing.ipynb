# %%
from bokeh.io import output_notebook
from bokeh.plotting import figure, show
N = 1000
import numpy as np

# %%
x = np.linspace(-5,5,100)
y = x**2
output_notebook()
# Out:
#     <div class="bk-root">
#         <a href="https://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="7ab5ba83-ed58-4230-a1f5-7928319703b3">Loading BokehJS ...</span>
#     </div>

# %%
p = figure()
p.line(x, y)
# Out:
# GlyphRenderer(id='e7c0d4b3-307b-4e43-ad72-b756e67da78a', ...)

# %%
show(p)
# Out:
# <div class="bk-root">
#     <div class="bk-plotdiv" id="77fab60d-6346-44a1-a2e2-5464e3d8c468"></div>
# </div>

# %%
from ipywidgets import interact
import numpy as np

from bokeh.io import push_notebook, show, output_notebook
from bokeh.plotting import figure
output_notebook()
# Out:
#     <div class="bk-root">
#         <a href="https://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="c5d570e6-2a15-4adc-a306-e239b2efc368">Loading BokehJS ...</span>
#     </div>

# %%
x = np.linspace(-5,5,100)
y = x**2

from bokeh.layouts import widgetbox
from bokeh.models.widgets import Slider

# %%
p = figure(title = "Basic Quadratic")
r = p.line(x, y)
r2 = p.circle(x, y)

# %%
a = Slider(start = -5, end = 5, value = 0, step = 0.1, title = "a")
b = Slider(start = -5, end = 5,  value = 0, step = 0.1)
c = Slider(start = -5, end = 5,  value = 0, step = 0.1)

# %%
show(p, notebook_handle=True)
# Out:
# <div class="bk-root">
#     <div class="bk-plotdiv" id="328ca3b3-158d-439f-b087-126cf1dd7d5e"></div>
# </div>
# <p><code>&lt;Bokeh Notebook handle for <strong>In[9]</strong>&gt;</code></p>

# %%
interact(update, f = ["Standard Form", "Factored Form", "Vertex Form"], a=(-5,5,0.1), b=(-5,5,0.1), c=(-5,5,0.1) )
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-10-0175cdccfc8f> in <module>()
# ----> 1 interact(update, f = ["Standard Form", "Factored Form", "Vertex Form"], a=(-5,5,0.1), b=(-5,5,0.1), c=(-5,5,0.1) )
#
# NameError: name 'update' is not defined

# %% [markdown]
# ## Interactions with Bokeh
#
# Every widget has either an `.on_change` method that takes an attribute name and one or more event handlers as parameters; `(attr, old, new)`.

# %%
def my_text_input_handler(attr, old, new):
    print("Previous label: " + old)
    print("Updated label: " + new)

text_input = TextInput(value="default", title="Label:")
text_input.on_change("value", my_text_input_handler)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-11-e2042e60ad57> in <module>()
#       3     print("Updated label: " + new)
#       4
# ----> 5 text_input = TextInput(value="default", title="Label:")
#       6 text_input.on_change("value", my_text_input_handler)
#
# NameError: name 'TextInput' is not defined

# %% [markdown]
# ## Typical Objects
#
# - Buttons
#
# - Checkbox Button Group
#
# - Checkbox Group
#
# - Data Table
#
# - Dropdown Menus
#
# - Multiselect
#
# - Radio Button Group
#
# - Radio Group
#
# - Selection Widget
#
# - Slider!

# %%
from bokeh.io import output_file, show
from bokeh.layouts import widgetbox
from bokeh.models.widgets import Button

output_file("button.html")

button = Button(label="BUTTONS", button_type="warning")

show(widgetbox(button))
# Out:
# <div class="bk-root">
#     <div class="bk-plotdiv" id="ab90e480-04b4-4557-90f4-711333415541"></div>
# </div>

# %%
from bokeh.io import output_file, show
from bokeh.layouts import widgetbox
from bokeh.models.widgets import Slider

output_file("slider.html")

x = np.linspace(-5,5,100)
y = x**2

p = figure(title = "Basic Quadratic")
r = p.line(x, y)
r2 = p.circle(x, y)

slider = Slider(start=0, end=10, value=1, step=.1, title="Stuff")

def update(f, a = 1, b = 0, c = 0):
    if f == "Standard Form": func = a*x**2 + b*x + c
    elif f == "Factored Form": func = a*(x - b)*(x + c)
    elif f == "Vertex Form": func = a*(x - b)**2 + c
    r.data_source.data['y'] = func
    r2.data_source.data['y'] = func
    push_notebook()
    
    
show(widgetbox(slider))
# Out:
# <div class="bk-root">
#     <div class="bk-plotdiv" id="c509309b-2e9e-4435-9cc4-80d884afcda5"></div>
# </div>

# %%
from bokeh.io import output_file, show
from bokeh.layouts import widgetbox
from bokeh.models.widgets import Button, RadioButtonGroup, Select, Slider

output_file("layout_widgets.html")

# create some widgets
slider = Slider(start=0, end=10, value=1, step=.1, title="Slider")
button_group = RadioButtonGroup(labels=["Option 1", "Option 2", "Option 3"], active=0)
select = Select(title="Option:", value="foo", options=["foo", "bar", "baz", "quux"])
button_1 = Button(label="Button 1")
button_2 = Button(label="Button 2")

# put the results in a row
show(widgetbox(button_1, slider, button_group, select, button_2, width=300))
# Out:
# <div class="bk-root">
#     <div class="bk-plotdiv" id="44b4bb5e-7a9f-45b1-9dd3-b2379cc3b356"></div>
# </div>

# %%
output_notebook()
# Out:
#     <div class="bk-root">
#         <a href="https://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="b53809d9-f8c5-4bec-a51d-95df770f47a5">Loading BokehJS ...</span>
#     </div>

# %%
from bokeh.io import output_notebook, show
from bokeh.plotting import figure
plot = figure(plot_width=400, tools = 'pan, box_zoom')
plot.circle([0, 3, 4, 5], [3, 2, 1, 6])

show(plot)

# %%
# %matplotlib notebook
import matplotlib.pyplot as plt
import numpy as np
import sympy as sy

# %%
x = np.linspace(0, 1, 10)

def f(x):
    return x**0.5

plt.figure()
plt.plot(x, f(x))
plt.axhline(4) #horizontal line at y=4
plt.ylim(0,5)
# Out:
# <img src="data:image/png;base64,...">
# (0, 5)

# %%
plt.axhline?
